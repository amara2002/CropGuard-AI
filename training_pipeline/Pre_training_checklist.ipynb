# %%
import os

# Define the path where your split data lives
train_path = r"C:\Users\Amara Nyei\Desktop\Model_Training\final_dataset\train"

# Verify the 16 classes are visible to Python
if os.path.exists(train_path):
    classes = os.listdir(train_path)
    print(f"✅ Connection Successful!")
    print(f"Found {len(classes)} classes ready for CropGuard training.")
else:
    print("❌ Error: Python cannot find the folder. Check the path name!")
# Out:
# ✅ Connection Successful!
# Found 16 classes ready for CropGuard training.
