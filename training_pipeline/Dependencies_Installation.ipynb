# %% [markdown]
# # Installation of Dependencies

# %%
# !pip install torch torchvision torchaudio
# !pip install matplotlib pandas opencv-python albumentations
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# ...
#   Using cached torchvision-0.26.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
# Using cached torchvision-0.26.0-cp313-cp313-win_amd64.whl (4.3 MB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached filelock-3.25.2-py3-none-any.whl (26 kB)
# ...
#
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
#    ---------------------------------------- 0/5 [networkx]
# ...

# %% [markdown]
# # Testing or Verification

# %%
import torch
import torchvision
import matplotlib

print(f"Torch Version: {torch.__version__}")
print(f"Is GPU available? {'✅ Yes' if torch.cuda.is_available() else '❌ No, using CPU'}")

# If you have a GPU, this will tell you which one
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
# Out:
# Torch Version: 2.11.0+cpu
# Is GPU available? ❌ No, using CPU

# %%
# !pip install grad-cam opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#      ----- ---------------------------------- 1.0/7.8 MB 6.0 MB/s eta 0:00:02
#      -------- ------------------------------- 1.6/7.8 MB 3.6 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.1/7.8 MB 4.5 MB/s eta 0:00:02
#      ---------------- ----------------------- 3.1/7.8 MB 4.0 MB/s eta 0:00:02
#      ---------------- ----------------------- 3.1/7.8 MB 4.0 MB/s eta 0:00:02
#      ------------------ --------------------- 3.7/7.8 MB 2.8 MB/s eta 0:00:02
#      -------------------------- ------------- 5.2/7.8 MB 3.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 5.8/7.8 MB 3.4 MB/s eta 0:00:01
#      -------------------------------- ------- 6.3/7.8 MB 3.4 MB/s eta 0:00:01
# ...

# %%
# !pip install fastapi uvicorn python-multipart
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ---------------------------------------- 0/6 [python-multipart]
#    ------ --------------------------------- 1/6 [click]
#    ------ --------------------------------- 1/6 [click]
#    ------ --------------------------------- 1/6 [click]
#    ------------- -------------------------- 2/6 [annotated-doc]
#    -------------------- ------------------- 3/6 [uvicorn]
#    -------------------- ------------------- 3/6 [uvicorn]
#    -------------------- ------------------- 3/6 [uvicorn]
#    -------------------- ------------------- 3/6 [uvicorn]
#    -------------------- ------------------- 3/6 [uvicorn]
#    -------------------- ------------------- 3/6 [uvicorn]
#    -------------------- ------------------- 3/6 [uvicorn]
#    -------------------------- ------------- 4/6 [starlette]
#    -------------------------- ------------- 4/6 [starlette]
#    -------------------------- ------------- 4/6 [starlette]
# ...
